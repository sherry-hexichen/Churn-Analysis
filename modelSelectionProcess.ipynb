# %% [markdown]
# <a href="https://colab.research.google.com/github/sherry-hexichen/Churn-Analysis/blob/master/modelSelectionProcess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pycaret

# %%
from pycaret.classification import *
import numpy as np
import pandas as pd
import math
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-afd97b52-b993-464a-aa4f-ad1eccebd8a0" name="files[]" multiple disabled />
#      <output id="result-afd97b52-b993-464a-aa4f-ad1eccebd8a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving final_data.csv to final_data.csv

# %%
import io
dataset = pd.read_csv(io.BytesIO(uploaded['final_data.csv']))

# %%
dataset.head()
# Out:
#    Unnamed: 0  ... nearby_third_party
# 0           0  ...                 18
# 1           1  ...                 18
# 2           2  ...                 18
# 3           3  ...                 18
# 4           4  ...                 18
#
# [5 rows x 34 columns]

# %%
dataset = dataset.drop(['Unnamed: 0', 'id'], axis=1)

# %%
dataset = dataset[dataset['retained_flag'] != 2]

# %%
dataset
# Out:
#         ro_dealerid             ro_vin  ...  nearby_same_dealer  nearby_third_party
# 0              5984  1C6RR6FG6ES377813  ...                   0                  18
# 1              5984  1C4RJEAGXHC707971  ...                   0                  18
# 2              5984  2C4RC1GG0DR788071  ...                   0                  18
# 3              5984  1C3CDFAA3FD435371  ...                   0                  18
# 4              5984  3D4PG5FV0AT231062  ...                   0                  18
# ...             ...                ...  ...                 ...                 ...
# 191483       100742  2T1BR32E14C264915  ...                   5                  19
# 191484       100742  JT3GN87R9Y0163961  ...                   5                  19
# 191485       100742  5TBRN34161S182064  ...                   5                  19
# 191486       100742  3TMMU52N86M002466  ...                   5                  19
# ...

# %%
dataset.columns
# Out:
# Index(['ro_dealerid', 'ro_vin', 'avg_ro_labor_price', 'avg_ro_parts_price',
#        'avg_customerpay', 'avg_customerpay_value', 'avg_warrantypay',
#        'avg_warrantypay_value', 'avg_otherpay', 'avg_otherpay_value',
#        'vehicle_warranty_date', 'vehicle_warranty_mileage', 'max_ro_mileage',
#        'recency', 'frequency', 'vehicle_age', 'last_service_date',
#        'cust_postal_code', 'cust_city', 'cust_state_code', 'retained_flag',
#        'vehicle_warranty_service_status', 'market_value', 'body_class',
#        'reliability', 'luxury', 'ronum', 'dealer_postal_code', 'distance',
#        'dealer_location_population', 'nearby_same_dealer',
#        'nearby_third_party'],
#       dtype='object')

# %%
features = dataset[['avg_ro_labor_price', 'avg_ro_parts_price',
       'avg_customerpay', 'avg_customerpay_value',
       'avg_warrantypay', 'avg_warrantypay_value', 'avg_otherpay',
       'avg_otherpay_value',
       'vehicle_warranty_mileage', 'max_ro_mileage', 'recency',
       'frequency', 'vehicle_age',
       'vehicle_warranty_service_status',
       'market_value', 'body_class', 'reliability', 'luxury', 'ronum',
       'distance', 'dealer_location_population',
       'nearby_same_dealer', 'nearby_third_party','retained_flag']]

# %%
Model = setup(data = features, target ='retained_flag', session_id=123, train_size=0.75, numeric_features=[
       'avg_ro_labor_price', 'avg_ro_parts_price',
       'avg_customerpay', 'avg_customerpay_value', 'avg_warrantypay',
       'avg_warrantypay_value', 'avg_otherpay', 'avg_otherpay_value',
       'vehicle_warranty_mileage', 'max_ro_mileage', 'recency',
       'frequency', 'vehicle_age','market_value','reliability','distance','nearby_same_dealer', 'nearby_third_party'])
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_303a0566_96d4_11ea_9ccb_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_303a0566_96d4_11ea_9ccb_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_303a0566_96d4_11ea_9ccb_0242ac1c0002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_303a0566_96d4_11ea_9ccb_0242ac1c0002row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_303a0566_96d4_11ea_9ccb_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_303a0566_96d4_11ea_9ccb_0242ac1c0002row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_2d3c76d4_96d7_11ea_9ccb_0242ac1c0002 th {
#           text-align: left;
#     }    #T_2d3c76d4_96d7_11ea_9ccb_0242ac1c0002row0_col0 {
#             text-align:  left;
#         }    #T_2d3c76d4_96d7_11ea_9ccb_0242ac1c0002row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2d3c76d4_96d7_11ea_9ccb_0242ac1c0002row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2d3c76d4_96d7_11ea_9ccb_0242ac1c0002row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2d3c76d4_96d7_11ea_9ccb_0242ac1c0002row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_2d3c76d4_96d7_11ea_9ccb_0242ac1c0002row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2d3c76d4_96d7_11ea_9ccb_0242ac1c0002row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
# ...
